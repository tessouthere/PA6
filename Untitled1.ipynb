# %%
import math
import mpmath

class calc():
    
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
        
    def addition(num1,num2):
        print("Addition=",num1+num2)

    def subtraction(num1,num2):
        print("Subtraction=",num1-num2)

    def multiplication(num1,num2):
        print("Multiplication=",num1*num2)

    def division(num1,num2):
        print("Division=",num1/num2)
        
    def sq(num1):
        print("The number squared is",num1**2)
    
    def power(num1,num2):
        power=num1**num2
        print(f"{num1} to the power of {num2} is {power}")
        
    def squareroot(num1):
        math.sqrt(num1)
        print("The square root of the number is",math.sqrt(num1))

    def otherroot(num1,num2):
        print(f"The root of {num1} with base {num2} is",math.pow(num1,(1/num2)))
        
    def absolute(num1):
        if num1>0:
            print("The absolute value is",num1,".")
        else:
            print("The absolute value is",num1*(-1),".")
        
    def factorial(num1):
        print(f"The factorial of {num1} is {math.factorial(num1)}.")
        
    def timespi(num1):
        print(f"The value of {num1} times pi is",num1*math.pi)
        
    def log(num1,base=10):
        print(f"The log of {num1} is",math.log(num1,base))
    
    def natlog(num1):
        print(f"The natural log of {num1} is",math.log(num1))
        
    def area(*args):
        for x in args:
            if x==r:
                value=(r**2)*math.pi
                print(f"The area of the circle is {value}.")
            elif x==squarelength:
                print(f"The area of the square is {squarelength**2}.")
            elif x==width:
                print(f"The area of the rectangle is {length*width}.")
                break
            else:
                print("The area of the triangle is",(base*height)/2)
                
    def perim(*args):
        for x in args:
            if x==r:
                value=2*math.pi*r
                print(f"The perimeter of the circle is {value}.")
            elif x==squarelength:
                print(f"The perimeter of the square is {squarelength*4}.")
            elif x==width:
                print(f"The perimeter of the rectangle is {2*(length+width)}.")
                break
            else:
                print("The perimeter of the triangle is",(side1+side2+side3))

        

while True:
    print("Basic Arithemtic Operations:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("Operations on one number:")
    print("5.  Squared")
    print("6.  Power")
    print("7.  Square Root")
    print("8.  Other Root")
    print("9.  Absolute Value")
    print("10. Factorial")
    print("11. Multiply by pi.")
    print("12. Log")
    print("13. Natural Log")
    print("Geometric Operations:")
    print("14. Area")
    print("15. Perimeter")
    choice=int(input("Enter your choice(1-10):"))

    if choice==1:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.addition(num1,num2)


    elif choice==2:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.subtraction(num1,num2)
    
    elif choice==3:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.multiplication(num1,num2)
    
    elif choice==4:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        if num2 == 0:
            print('Infinity')
        else:
            calc.division(num1,num2)
                
    elif choice==5:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.sq(num1,num2)
        
    elif choice==6:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.power(num1)
        
    elif choice==7:
        num1=int(input("Enter 1st Number: "))
        calc.squareroot(num1)
        
    elif choice==8:
        num1=int(input("Enter 1st Number: "))
        num2=int(input("Enter 2nd Number: "))
        calc.otherroot(num1,num2)
        
    elif choice==9:
        num1=int(input("Enter 1st Number: "))
        calc.absolute(num1)
        
    elif choice==10:
        num1=int(input("Enter 1st Number: "))
        calc.factorial(num1)
        
    elif choice==11:
        num1=int(input("Enter 1st Number: "))
        
    elif choice==12:
        num1=int(input("Enter a Number: "))
        calc.log(num1)
        
    elif choice==13:
        num1=int(input("Enter a Number: "))
        calc.natlog(num1)
    
    elif choice==14:
        shape=int(input("What is the shape? Enter 0 for circle, 1 for square, 2 for rectangle, 3 for triangle."))
        if shape==0:
            r=int(input("Enter the radius of the circle: "))           
            calc.area(r)
        elif shape==1:
            squarelength=int(input("Enter the length of the square:" ))
            calc.area(squarelength)
        elif shape==2:
            width=int(input("Enter the width: "))
            length=int(input("Enter the length: "))            
            calc.area(width,length)
        elif shape==3:
            base=int(input("Enter the base of the triangle: "))
            height=int(input("Enter the height of the triangle: "))
            calc.area(base,height)
            
    elif choice==15:
        shape=int(input("What is the shape? Enter 0 for circle, 1 for square, 2 for rectangle, 3 for triangle."))
        if shape==0:
            r=int(input("Enter the radius of the circle: "))           
            calc.perim(r)
        elif shape==1:
            squarelength=int(input("Enter the length of the square:" ))
            calc.perim(squarelength)
        elif shape==2:
            width=int(input("Enter the width: "))
            length=int(input("Enter the length: "))            
            calc.perim(width,length)
        elif shape==3:
            side1=int(input("Enter side length: "))
            side2=int(input("Enter side length: "))
            side3=int(input("Enter side length: "))
            calc.perim(side1,side2,side3)
    else:
        print("Wrong Choice")
# Out:
# Basic Arithemtic Operations:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Operations on one number:
# 5.  Squared
# 6.  Power
# 7.  Square Root
# 8.  Other Root
# 9.  Absolute Value
# 10. Factorial
# 11. Multiply by pi.
# 12. Log
# 13. Natural Log
# Geometric Operations:
# 14. Area
# 15. Perimeter
